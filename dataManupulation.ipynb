# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.DataFrame({
    'height_cm': [150,125,160,167,175,157,145,180,182],
    'weight_kg':[50,52,54,55,57,60,65,68,70]
})

# %%
data
# Out:
#    height_cm  weight_kg
# 0        150         50
# 1        125         52
# 2        160         54
# 3        167         55
# 4        175         57
# 5        157         60
# 6        145         65
# 7        180         68
# 8        182         70

# %%
plt.plot(data)
plt.xlabel("height_cm")
plt.ylabel("weight_kg")
plt.show()

# %%
df = sns.load_dataset('car_crashes')
df.head(10)
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
# 5   13.6     5.032    3.808          10.744       12.920       835.50
# 6   10.8     4.968    3.888           9.396        8.856      1068.73
# 7   16.2     6.156    4.860          14.094       16.038      1137.87
# 8    5.9     2.006    1.593           5.900        5.900      1273.89
# 9   17.9     3.759    5.191          16.468       16.826      1160.13
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA
# 5      139.91     CO
# 6      167.02     CT
# ...

# %%
df.tail(10)
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 41   19.4     6.014    6.402          19.012       16.684       669.31
# 42   19.5     4.095    5.655          15.990       15.795       767.91
# 43   19.4     7.760    7.372          17.654       16.878      1004.75
# 44   11.3     4.859    1.808           9.944       10.848       809.38
# 45   13.6     4.080    4.080          13.056       12.920       716.20
# 46   12.7     2.413    3.429          11.049       11.176       768.95
# 47   10.6     4.452    3.498           8.692        9.116       890.03
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 50   17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses abbrev
# 41       96.87     SD
# 42      155.57     TN
# 43      156.83     TX
# 44      109.48     UT
# 45      109.61     VT
# 46      153.72     VA
# 47      111.62     WA
# ...

# %%
df.columns
# Out:
# Index(['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous',
#        'ins_premium', 'ins_losses', 'abbrev'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     str
# dtypes: float64(7), str(1)
# memory usage: 3.3 KB

# %%
df.describe()
# Out:
#            total   speeding    alcohol  not_distracted  no_previous  \
# count  51.000000  51.000000  51.000000       51.000000    51.000000
# mean   15.790196   4.998196   4.886784       13.573176    14.004882
# std     4.122002   2.017747   1.729133        4.508977     3.764672
# min     5.900000   1.792000   1.593000        1.760000     5.900000
# 25%    12.750000   3.766500   3.894000       10.478000    11.348000
# 50%    15.600000   4.608000   4.554000       13.857000    13.775000
# 75%    18.500000   6.439000   5.604000       16.140000    16.755000
# max    23.900000   9.450000  10.038000       23.661000    21.280000
#
#        ins_premium  ins_losses
# count    51.000000   51.000000
# mean    886.957647  134.493137
# std     178.296285   24.835922
# min     641.960000   82.750000
# 25%     768.430000  114.645000
# 50%     858.970000  136.050000
# 75%    1007.945000  151.870000
# max    1301.520000  194.780000

# %% [markdown]
# ##How to Deal with Null Values

# %%
ex = pd.read_csv("student_performance.csv")
ex
# Out:
#      StudentID  Gender  Age ParentEducation  StudyHoursPerWeek  \
# 0         1001    Male   15       Secondary               10.6
# 1         1002    Male   18          Higher                9.6
# 2         1003    Male   18       Secondary                5.0
# 3         1004    Male   19       Secondary               23.5
# 4         1005    Male   21       Secondary               18.7
# ..         ...     ...  ...             ...                ...
# 495       1496    Male   22       Secondary               31.0
# 496       1497    Male   21          Higher               14.0
# 497       1498  Female   16         Primary               22.1
# 498       1499    Male   19          Higher                1.7
# 499       1500    Male   22          Higher                NaN
#
#      AttendanceRate InternetAccess  MidtermScore  FinalScore  Result
# 0              39.8            Yes          23.2        31.5       0
# 1              71.2             No          44.9        40.4       0
# ...

# %%
gender_counts = ex["Gender"].value_counts()

# Create pie chart
plt.figure(figsize=(6,6))
plt.pie(
    gender_counts,
    labels=gender_counts.index,
    autopct=lambda p: f'{p:.1f}%\n({int(round(p/100*gender_counts.sum()))})',
    startangle=90,
    shadow=True
)

plt.title("Gender Distribution of Students", fontsize=14, fontweight='bold')
plt.ylabel("")  # Remove default y-label
plt.tight_layout()
plt.show()

# %%
ex.isnull().sum()
# Out:
# StudentID              0
# Gender                 0
# Age                    0
# ParentEducation      126
# StudyHoursPerWeek     18
# AttendanceRate        28
# InternetAccess         0
# MidtermScore           0
# FinalScore             0
# Result                 0
# dtype: int64

# %%
for col in ex.columns:
    if ex[col].isnull().sum() > 0:
        if ex[col].dtype == "object":
            ex[col] = ex[col].fillna(ex[col].mode()[0])
        else:
            ex[col] = ex[col].fillna(ex[col].median())


         
ex.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[103], line 6
#       2     if ex[col].isnull().sum() > 0:
#       3         if ex[col].dtype == "object":
#       4             ex[col] = ex[col].fillna(ex[col].mode()[0])
#       5         else:
# ----> 6             ex[col] = ex[col].fillna(ex[col].median())
#       7
#       8
#       9
#
# File c:\Users\user\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# ...
